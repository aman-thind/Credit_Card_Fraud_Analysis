# %%
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load and check data
data=pd.read_csv('./creditcard.csv')
print(f'This dataset has {data.shape[0]} rows and {data.shape[1]} columns')
# Out:
# This dataset has 284807 rows and 31 columns

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#finding missing values
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# There is no missing values in this dataset

# %%
#Let's look into more details to the data
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# The data set contains 284,807 transactions. The mean amount of all the transactions is 88.35USD while the largest transaction recorded in this data set amounts to 25,691USD. This shows that the distribution of the transactions is heavily right-skewed. The vast majority of transactions are relatively small and only a small fraction of transactions are close to the maximum.

# %%
plt.figure(figsize=(10,4))
plt.title('Time Distribution')
sns.distplot(data.Time)

# %%
plt.figure(figsize=(10,4))
plt.title('Distribution of transaction value')
sns.distplot(data.Amount)

# %%
#fraud vs. normal transactions 
counts = data.Class.value_counts()
normal = counts[0]
fraudulent = counts[1]
perc_normal = (normal/(normal+fraudulent))*100
perc_fraudulent = (fraudulent/(normal+fraudulent))*100
print('There are {} non-fraudulent transactions ({:.3f}%) and {} fraudulent transactions ({:.3f}%).'.format(normal, perc_normal, fraudulent, perc_fraudulent))
# Out:
# There are 284315 non-fraudulent transactions (99.827%) and 492 fraudulent transactions (0.173%).

# %% [markdown]
# As expected, most transactions are non-fraudulent. The following visualization underlines this significant contrast

# %%
plt.figure(figsize=(7,5))
sns.barplot(x=counts.index, y=counts)
plt.title('Count of Fraudulent vs. Non-Fraudulent Transactions', size=14)
plt.ylabel('Count')
plt.xlabel('Class (0:Non-Fraudulent, 1:Fraudulent)')
# Out:
# Text(0.5, 0, 'Class (0:Non-Fraudulent, 1:Fraudulent)')

# %%
#lets analyse the relationship between Amount, Time, and Class
sns.FacetGrid(data, hue = 'Class', height = 5).map(plt.scatter, 'Time', 'Amount').add_legend()

# %%
#Exploring if there are differences between the Fraud and Non-Fraud classes
#We separate the classes
fraud = data[data.Class == 1]
non_fraud = data[data.Class == 0]

#We use describe for the Time and Amount columns
print("Fraud values")
fraud[["Time","Amount"]].describe()
# Out:
# Fraud values
#                 Time       Amount
# count     492.000000   492.000000
# mean    80746.806911   122.211321
# std     47835.365138   256.683288
# min       406.000000     0.000000
# 25%     41241.500000     1.000000
# 50%     75568.500000     9.250000
# 75%    128483.000000   105.890000
# max    170348.000000  2125.870000

# %%
print("Non Fraud values")
non_fraud[["Time","Amount"]].describe()
# Out:
# Non Fraud values
#                 Time         Amount
# count  284315.000000  284315.000000
# mean    94838.202258      88.291022
# std     47484.015786     250.105092
# min         0.000000       0.000000
# 25%     54230.000000       5.650000
# 50%     84711.000000      22.000000
# 75%    139333.000000      77.050000
# max    172792.000000   25691.160000

# %% [markdown]
# We can see that half of them are usually small amount frauds: from 0 to 25% the amount is equal or less than 1 USD, from 25 to 50% between 1 and 9 USD.
#
# We also found that in both cases there could be outliers, especially in the cases of Non Fraud (25691 USD)

# %%
# Lets check any significant correlations
correlations = data.corr()
f,ax = plt.subplots(figsize=(30,30))
sns.heatmap(correlations, annot = True)

# %% [markdown]
# There seem to be relatively little significant correlations for such a big number of variables. This can probably be attributed to two factors:
#
# -The data was prepared using a PCA, therefore our predictors are principal components.
#
# -The huge class imbalance might distort the importance of certain correlations with regards to our class variable.

# %%
# split normalize data
x = data.drop("Class", axis=1)
y = data.Class

# %%
#splitting data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 0)

# %%
# See if both the train and test label distribution are similarly distributed
print("Label distribution y_train")
print(y_train.value_counts(normalize=True))
print("Label distribution y_test")
print(y_test.value_counts(normalize=True))
# Out:
# Label distribution y_train
# 0    0.998271
# 1    0.001729
# Name: Class, dtype: float64
# Label distribution y_test
# 0    0.998276
# 1    0.001724
# Name: Class, dtype: float64

# %% [markdown]
# Our dataframe is not balanced, so we will create a sub-sample where the classes are distributed 70/30. With this technique the algorithm can work better but a lot of information is lost that could be useful.
#
# We will use X_train and y_train to do this, reserving the Test to validate .
#
# I will take all the cases of Class=1, and then, to maintain the 70/30 proportion, taking 919 data of Class=0, finally using pd.concat, create the sub_sample (30% = 330, 70%=919)

# %%
#First with value counts we see how many values we have from each class
y_train.value_counts()
# Out:
# 0    190490
# 1       330
# Name: Class, dtype: int64

# %%
# here we have all fraud cases
X_fraud = data.loc[y_train.loc[y_train == 1].index]

# %%
# 919 values where Class=0
y_non_fraud = data.loc[y_train.loc[y_train == 0].index][:919]

# %%
#concat
sub_sample = pd.concat([X_fraud,y_non_fraud],axis=0)

# %%
#finally a sub_sample with 70/30 proportions
sub_sample.shape
# Out:
# (1249, 31)

# %%
new_df_class = sub_sample.Class.value_counts().reset_index()
sns.barplot(x="index",y="Class",data=new_df_class)
sns.despine()
plt.title("Fraud class frequency", size=15)
plt.xlabel("Classes")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# split normalize data
x_new = sub_sample.drop("Class",axis=1)
y_new = sub_sample.Class

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_new, y_new)
pred_rf=rf.predict(x_test)
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print(confusion_matrix(y_test,pred_rf))
print(accuracy_score(y_test,pred_rf))
print(classification_report(y_test,pred_rf))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [[93185   640]
#  [   24   138]]
# 0.9929351931650122
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     93825
#            1       0.18      0.85      0.29       162
#
#     accuracy                           0.99     93987
#    macro avg       0.59      0.92      0.65     93987
# weighted avg       1.00      0.99      1.00     93987

# %% [markdown]
# Random Forest was used in developing fraud detection model to classify a transaction as fraudulent or legitimate. Three metrics were used in evaluating their performances.
# Performance improvement could be achieved through developing a fraud detection model using a combination of different algorithms.
#
# Having a data set with non-anonymized features would make this particularly interesting as outputting the feature importance would enable one to see what specific factors are most important for detecting fraudulent transactions.

# %%
import pickle

# Saving model to disk
pickle.dump(rf, open('model.pkl','wb'))
